# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpalatha-H/CodSoft_internship/blob/main/CodSoft_internship_Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Credit Card Fraud Detection
# Build a machine learning model to identify fraudulent credit card
# transactions.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
# check for na values
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# check for duplicates
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 58214    False
# 58215    False
# 58216    False
# 58217    False
# 58218    False
# Length: 58219, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 239

# %%
# drop duplicates
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57980 entries, 0 to 58218
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    57980 non-null  int64
#  1   V1      57980 non-null  float64
#  2   V2      57980 non-null  float64
#  3   V3      57980 non-null  float64
#  4   V4      57980 non-null  float64
#  5   V5      57980 non-null  float64
#  6   V6      57980 non-null  float64
#  7   V7      57980 non-null  float64
#  8   V8      57980 non-null  float64
#  9   V9      57979 non-null  float64
#  10  V10     57979 non-null  float64
#  11  V11     57979 non-null  float64
#  12  V12     57979 non-null  float64
#  13  V13     57979 non-null  float64
#  14  V14     57979 non-null  float64
#  15  V15     57979 non-null  float64
#  16  V16     57979 non-null  float64
#  17  V17     57979 non-null  float64
#  18  V18     57979 non-null  float64
#  19  V19     57979 non-null  float64
#  20  V20     57979 non-null  float64
#  21  V21     57979 non-null  float64
#  22  V22     57979 non-null  float64
#  23  V23     57979 non-null  float64
#  24  V24     57979 non-null  float64
#  25  V25     57979 non-null  float64
#  26  V26     57979 non-null  float64
#  27  V27     57979 non-null  float64
#  28  V28     57979 non-null  float64
#  29  Amount  57979 non-null  float64
#  30  Class   57979 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 14.2 MB

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.Class.unique()
# Out:
# array([ 0.,  1., nan])

# %%
df.Amount.describe()
# Out:
# count    57979.000000
# mean        95.280654
# std        259.068657
# min          0.000000
# 25%          7.690000
# 50%         26.160000
# 75%         87.980000
# max      12910.930000
# Name: Amount, dtype: float64

# %% [markdown]
# # separating data for analysis

# %%
legit = df[df.Class==0]
fraud = df[df.Class==1]

# %%
print(legit.shape)
# Out:
# (57819, 31)

# %%
print(fraud.shape)
# Out:
# (160, 31)

# %% [markdown]
# #Stratical measure of the data

# %%
legit['Amount'].describe()
# Out:
# count    57819.000000
# mean        95.285787
# std        259.156565
# min          0.000000
# 25%          7.745000
# 50%         26.230000
# 75%         87.895000
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     160.000000
# mean       93.425687
# std       225.763863
# min         0.000000
# 25%         1.000000
# 50%         4.245000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# # Compare the values for both transactions

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    31383.895726 -0.214068 -0.027210  0.719243  0.154026 -0.244558
# 1.0    28335.375000 -7.165410  5.159692 -9.694508  5.603985 -5.297972
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.107675 -0.094701  0.044159  0.076481  ...  0.047304 -0.030926
# 1.0   -2.179867 -7.560791  3.478372 -3.399071  ...  0.439411  0.864755
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.105604 -0.039087  0.007219  0.135367  0.019796  0.002728  0.003879
# 1.0   -0.209271 -0.269485 -0.077961  0.235786  0.128597  0.572709  0.034909
#
#           Amount
# Class
# 0.0    95.285787
# 1.0    93.425688
#
# [2 rows x 30 columns]

# %% [markdown]
# #Under Sampling
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent transactions
#
# number of Fraudlent transactions is 30

# %% [markdown]
# Taking only 30 from legit

# %%
legit_sample = legit.sample(n=30)
legit_sample
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
#
# 3265   0.395025  0.407324  0.322389 -0.444576 -0.009689    67.46    0.0
# 2920   0.342135  0.072865  0.104995 -0.012694  0.031213    12.99    0.0
# 13785  0.712062  0.101851  0.321692 -0.037456  0.037789    73.61    0.0
# 4351   0.311580  0.012911 -0.523203 -0.031367  0.039164   149.97    0.0
# 48526  0.260224 -0.187981  0.312034  0.350689  0.161270    11.50    0.0
# 31097  0.101722  0.295663 -0.076959  0.073603  0.025952    13.40    0.0
#
# [30 rows x 31 columns]

# %% [markdown]
# Concatenating two DataFrames

# %%
# create new sample
new_df = pd.concat([legit_sample, fraud], axis =0)
new_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 12437  21807  0.898614  0.033896 -0.083297  1.256326  0.554091  0.702342
# 40810  40412 -1.281383 -0.315044  1.304127  1.283901  0.752309 -0.957189
# 38396  39380  1.117035 -0.640134  1.170036  1.042335 -1.065988  0.715537
# 27769  34699  1.060901  0.122563  0.640184  1.535093 -0.600619 -0.221202
# 35086  37953 -1.496218 -4.814797 -0.283268  1.465949 -2.669991  0.318931
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 12437  0.155668  0.196360  1.160759  ...  0.031511  0.278743 -0.027337
# 40810  0.387777 -0.242250  0.222080  ... -0.197653  0.144610  0.762322
# 38396 -0.944829  0.338029  1.864115  ... -0.255491 -0.381154 -0.142728
# 27769 -0.333575  0.133371  0.528970  ... -0.023667  0.170623 -0.139733
# 35086  0.996200 -0.097029  0.870745  ...  0.648368 -1.078013 -1.099180
#
#             V24       V25       V26       V27       V28   Amount  Class
# 12437 -0.708803  0.393032 -0.231545  0.011633  0.005579    89.99    0.0
# 40810  0.309280 -0.008313  0.497427 -0.005639 -0.178438    12.31    0.0
# 38396 -0.412422  0.451300  0.438943  0.029912  0.021688    47.45    0.0
# 27769  0.472956  0.616844 -0.308828  0.065397  0.047554    30.00    0.0
# 35086  0.645081 -0.458119  0.738539 -0.300877  0.242856  1376.66    0.0
#
# [5 rows x 31 columns]

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 1.0    160
# 0.0     30
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    27891.733333 -0.211231  0.003183  0.759521  0.442309 -0.590164
# 1.0    28335.375000 -7.165410  5.159692 -9.694508  5.603985 -5.297972
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.135869 -0.097127  0.336652  0.189854  ...  0.111530  0.004009
# 1.0   -2.179867 -7.560791  3.478372 -3.399071  ...  0.439411  0.864755
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.057699 -0.056396  0.014206  0.050026 -0.128893  0.020666  0.022106
# 1.0   -0.209271 -0.269485 -0.077961  0.235786  0.128597  0.572709  0.034909
#
#            Amount
# Class
# 0.0    136.741333
# 1.0     93.425688
#
# [2 rows x 30 columns]

# %% [markdown]
# # Splitting the data into Features & Targets

# %%
x = new_df.drop(['Class'], axis = 'columns')
y = new_df['Class']

# %% [markdown]
# #Split the data into training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
len(x_train)
# Out:
# 142

# %%
len(x_test)
# Out:
# 48

# %% [markdown]
# # Model Training
# Logistic Regression

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model Evaluation
# Accuracy score

# %%
model.score(x_test, y_test)
# Out:
# 0.9166666666666666

# %%
from sklearn.metrics import accuracy_score

# %%
x_train_prediction = model.predict(x_train)
x_train_accuracy =  accuracy_score(x_train_prediction, y_train)
print('Accuracy on train data:' , x_train_accuracy)
# Out:
# Accuracy on train data: 0.9929577464788732

# %%
x_test_prediction = model.predict(x_test)
x_test_accuracy =  accuracy_score(x_test_prediction, y_test)
print('Accuracy on test data:' , x_test_accuracy)
# Out:
# Accuracy on test data: 0.9166666666666666
